# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
at_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_match_parquet/away_team"):
    single_at = pd.read_parquet("drive/MyDrive/raw/raw_match_parquet/away_team/" + file)
    at_dataframe = pd.concat([at_dataframe, single_at], axis="rows", ignore_index=True)

at_dataframe
# Out:
#      match_id                  name                         slug gender  \
# 0    11675449  Davidovich Fokina A.  davidovich-fokina-alejandro      M
# 1    11675448               Ruud C.                  ruud-casper      M
# 2    11675444            Musetti L.              musetti-lorenzo      M
# 3    11675450             Sinner J.                sinner-jannik      M
# 4    11675446           Dimitrov G.              dimitrov-grigor      M
# ..        ...                   ...                          ...    ...
# 381  11703470           Lizarazo Y.             lizarazo-yuliana      F
# 382  11702248               Noel M.               noel-mallaurie      F
# 383  11701145          Nikolenko T.            nikolenko-tatyana      F
# 384  11701150              Drozd M.                   drozd-maya      F
# 385  11701141          Rachapudi P.         rachapudi-prathyusha      F
#
#      user_count            residence          birthplace height weight  \
# 0          8793           Fuengirola       Malaga, Spain   1.83     80
# 1         29533         Oslo, Norway        Oslo, Norway   1.83     77
# 2         22366              Carrara      Carrara, Italy   1.85     75
# 3         64879  Monte Carlo, Monaco  San Candido, Italy   1.88     68
# 4         22646  Monte Carlo, Monaco   Haskovo, Bulgaria   1.91     81
# ..          ...                  ...                 ...    ...    ...
# 381         248                 None    Cúcuta, Colombia   1.75   None
# 382         152                 None                None   None   None
# 383          75                 None                None   None   None
# 384          71                 None                None   None   None
# 385          27                 None                None   None   None
#
#             plays turned_pro current_prize total_prize  player_id  \
# 0    right-handed       2019       1509026     4476749     157456
# 1    right-handed       2015       2601211    13500643     119248
# 2    right-handed       2019       1598590     3901074     261015
# 3    right-handed       2018       6915316    12447135     206570
# 4    right-handed       2008       2252614    20583691      23581
# ..            ...        ...           ...         ...        ...
# 381  right-handed       None         22869      119050      42864
# 382  right-handed       None          1974       45447     108701
# 383          None       None          1472        1778     329809
# 384          None       None          1889        1931     421776
# 385          None       None           677        4594     205884
#
#     current_rank name_code     country                     full_name
# 0             26       DAV       Spain  Davidovich Fokina, Alejandro
# 1             11       RUU      Norway                  Ruud, Casper
# 2             27       MUS       Italy              Musetti, Lorenzo
# 3              4       SIN       Italy                Sinner, Jannik
# 4             14       DIM    Bulgaria              Dimitrov, Grigor
# ..           ...       ...         ...                           ...
# 381          837       LIZ    Colombia             Lizarazo, Yuliana
# 382          985       NOE      France               Noel, Mallaurie
# 383         None       NIK  Kazakhstan            Nikolenko, Tatyana
# 384         1142       DRO     Germany                   Drozd, Maya
# 385         1294       RAC       India         Rachapudi, Prathyusha
#
# [386 rows x 18 columns]

# %%
ats_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_match_parquet/away_team_score"):
    single_ats = pd.read_parquet("drive/MyDrive/raw/raw_match_parquet/away_team_score/" + file)
    ats_dataframe = pd.concat([ats_dataframe, single_ats], axis="rows", ignore_index=True)

ats_dataframe
# Out:
#      match_id current_score display_score period_1 period_2 period_3 period_4  \
# 0    11675449             1             1        7        2        1     None
# 1    11675448             2             2        1        7        7     None
# 2    11675444             0             0        2        2     None     None
# 3    11675450             2             2        6        6     None     None
# 4    11675446             2             2        6        7     None     None
# ..        ...           ...           ...      ...      ...      ...      ...
# 779  11701147             0             0        1        2     None     None
# 780  11701143             0             0        2        1     None     None
# 781  11701139             1             1        6        2        7     None
# 782  11701137             0             0        6        2     None     None
# 783  11701141             2             2        6        6     None     None
#
#     period_5 period_1_tie_break period_2_tie_break period_3_tie_break  \
# 0       None                  7               None               None
# 1       None               None               None                  9
# 2       None               None               None               None
# 3       None               None               None               None
# 4       None               None               None               None
# ..       ...                ...                ...                ...
# 779     None               None               None               None
# 780     None               None               None               None
# 781     None               None               None               None
# 782     None               None               None               None
# 783     None               None               None               None
#
#     period_4_tie_break period_5_tie_break normal_time
# 0                 None               None        None
# 1                 None               None        None
# 2                 None               None        None
# 3                 None               None        None
# 4                 None               None        None
# ..                 ...                ...         ...
# 779               None               None        None
# 780               None               None        None
# 781               None               None        None
# 782               None               None        None
# 783               None               None        None
#
# [784 rows x 14 columns]

# %%
event_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_match_parquet/event"):
    single_event = pd.read_parquet("drive/MyDrive/raw/raw_match_parquet/event/" + file)
    event_dataframe = pd.concat([event_dataframe, single_event], axis="rows", ignore_index=True)

event_dataframe
# Out:
#      match_id first_to_serve home_team_seed away_team_seed  custom_id  \
# 0    11675444              1              1           None  pvecsytkc
# 1    11675443              1              8           None    nTxsHRK
# 2    11674111              2           None              6    UrgsXrI
# 3    11674113              2           None           None    YzrsXrI
# 4    11674110              2              4             WC  RUbcseDDc
# ..        ...            ...            ...            ...        ...
# 759  11702042           None           None             10    yEqsdYw
# 760  11702216           None           None             WC  iCebsLtXd
# 761  11701932           None           None             14  ntKbsZtkc
# 762  11703525              2           None           None   bEOsPWTd
# 763  11703524              1              7           None  UmGcsqnpd
#
#     winner_code  default_period_count  start_datetime              match_slug  \
# 0             1                     3      1696147200         alcaraz-musetti
# 1             1                     3      1696230000            jarry-zverev
# 2             2                     3      1696250400         ofner-mannarino
# 3             2                     3      1696161600             ofner-thiem
# 4             2                     3      1696140000       mededovic-lehecka
# ..          ...                   ...             ...                     ...
# 759           1                     3      1696246200  karlovskiy-de-schepper
# 760           1                     3      1696251600           martaux-ortiz
# 761           2                     3      1696230000      murgett-troebinger
# 762           1                     3      1696252500         benson-milushev
# 763           1                     3      1696253400         panaras-morolli
#
#      final_result_only
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ..                 ...
# 759              False
# 760              False
# 761              False
# 762              False
# 763              False
#
# [764 rows x 10 columns]

# %%
ht_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_match_parquet/home_team"):
    single_ht = pd.read_parquet("drive/MyDrive/raw/raw_match_parquet/home_team/" + file)
    ht_dataframe = pd.concat([ht_dataframe, single_ht], axis="rows", ignore_index=True)

ht_dataframe
# Out:
#      match_id             name                        slug gender  user_count  \
# 0    11675449        Zverev A.            zverev-alexander      M       49973
# 1    11675448    Etcheverry T.     etcheverry-tomas-martin      M        5812
# 2    11675444       Alcaraz C.              alcaraz-carlos      M      120920
# 3    11675450      Nishioka Y.          nishioka-yoshihito      M        4166
# 4    11675446          Rune H.                 rune-holger      M       32906
# ..        ...              ...                         ...    ...         ...
# 431  11701152       Bednarz Z.             bednarz-zuzanna      F         220
# 432  11701146  Martellenghi E.           martellenghi-emma      F          33
# 433  11701145    Nava Elkin A.  nava-elkin-amanda-carolina      F          31
# 434  11701143     Cembranos P.             cembranos-paula      F          68
# 435  11701137    Zelinskaya D.            zelinskaya-daria      F          55
#
#                     residence                birthplace height weight  \
# 0         Monte Carlo, Monaco          Hamburg, Germany   1.98     90
# 1    La Plata -  Buenos Aires       La Plata, Argentina   1.96     82
# 2    El Palmar, Murcia, Spain  El Palmar, Murcia, Spain   1.83     68
# 3                  Mie, Japan                Mie, Japan    1.7     64
# 4     Charlottenlund, Denmark         Gentofte, Denmark   1.88     68
# ..                        ...                       ...    ...    ...
# 431                      None                      None   None   None
# 432                      None                      None   None   None
# 433                      None                      None   None   None
# 434                      None                      None   None   None
# 435                      None                      None   None   None
#
#             plays turned_pro current_prize total_prize  player_id  \
# 0    right-handed       2013       4017220    31525132      57163
# 1    right-handed       None       1199150     1863565     169496
# 2    right-handed       2018       8961193    18819228     275923
# 3     left-handed       2014       1020169     4723679      59281
# 4    right-handed       None       3451183     5975340     283070
# ..            ...        ...           ...         ...        ...
# 431          None       None          3712        6760     388600
# 432          None       None          1135        1472     455682
# 433          None       None          2841        3618     251345
# 434          None       None          3877        5169     419528
# 435          None       None          2353        4825     382898
#
#     current_rank name_code      country                    full_name
# 0              7       ZVE      Germany            Zverev, Alexander
# 1             30       ETC    Argentina     Etcheverry, Tomas Martin
# 2              2       ALC        Spain              Alcaraz, Carlos
# 3             47       NIS        Japan          Nishioka, Yoshihito
# 4              8       RUN      Denmark                 Rune, Holger
# ..           ...       ...          ...                          ...
# 431         1140       BED       Poland             Bednarz, Zuzanna
# 432         1329       MAR        Italy           Martellenghi, Emma
# 433         1196       NAV       Mexico  Nava Elkin, Amanda Carolina
# 434         1123       CEM  Switzerland             Cembranos, Paula
# 435         1307       ZEL       Russia            Zelinskaya, Daria
#
# [436 rows x 18 columns]

# %%
hts_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_match_parquet/home_team_score"):
    single_hts = pd.read_parquet("drive/MyDrive/raw/raw_match_parquet/home_team_score/" + file)
    hts_dataframe = pd.concat([hts_dataframe, single_hts], axis="rows", ignore_index=True)

hts_dataframe
# Out:
#      match_id current_score display_score period_1 period_2 period_3 period_4  \
# 0    11675445             1             1        4        6        2     None
# 1    11675444             2             2        6        6     None     None
# 2    11675440             1             1        4        6        1     None
# 3    11674114             1             1        4        6        3     None
# 4    11675443             2             2        6        6        6     None
# ..        ...           ...           ...      ...      ...      ...      ...
# 759  11701931             2             2        6        3       10     None
# 760  11703524             2             2        6        6     None     None
# 761  11703525             2             2        6        7     None     None
# 762  11703470             2             2        7        6     None     None
# 763  11703445             2             2        7        6     None     None
#
#     period_5 period_1_tie_break period_2_tie_break period_3_tie_break  \
# 0       None               None               None               None
# 1       None               None               None               None
# 2       None               None               None               None
# 3       None               None               None               None
# 4       None               None                  5               None
# ..       ...                ...                ...                ...
# 759     None               None               None               None
# 760     None               None               None               None
# 761     None               None               None               None
# 762     None               None               None               None
# 763     None                  7               None               None
#
#     period_4_tie_break period_5_tie_break normal_time
# 0                 None               None        None
# 1                 None               None        None
# 2                 None               None        None
# 3                 None               None        None
# 4                 None               None        None
# ..                 ...                ...         ...
# 759               None               None        None
# 760               None               None        None
# 761               None               None        None
# 762               None               None        None
# 763               None               None        None
#
# [764 rows x 14 columns]

# %%
round_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_match_parquet/round"):
    single_round = pd.read_parquet("drive/MyDrive/raw/raw_match_parquet/round/" + file)
    round_dataframe = pd.concat([round_dataframe, single_round], axis="rows", ignore_index=True)

round_dataframe
# Out:
#      match_id  round_id                   name                   slug  \
# 0    11697126        32            Round of 64            round-of-64
# 1    11697124        32            Round of 64            round-of-64
# 2    11697122        32            Round of 64            round-of-64
# 3    11697121        32            Round of 64            round-of-64
# 4    11697119        32            Round of 64            round-of-64
# ..        ...       ...                    ...                    ...
# 172  11701615         6            Round of 32            round-of-32
# 173  11701350         1  Qualification round 1  qualification-round-1
# 174  11701612         6            Round of 32            round-of-32
# 175  11701616         6            Round of 32            round-of-32
# 176  11701352         1  Qualification round 1  qualification-round-1
#
#     cup_round_type
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ..             ...
# 172             16
# 173           None
# 174             16
# 175             16
# 176           None
#
# [177 rows x 5 columns]

# %%
season_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_match_parquet/season"):
    single_season = pd.read_parquet("drive/MyDrive/raw/raw_match_parquet/season/" + file)
    season_dataframe = pd.concat([season_dataframe, single_season], axis="rows", ignore_index=True)

season_dataframe
# Out:
#      match_id  season_id                                 name  year
# 0    11675449      50091  ATP Beijing, China Men Singles 2023  2023
# 1    11675448      50091  ATP Beijing, China Men Singles 2023  2023
# 2    11675444      50091  ATP Beijing, China Men Singles 2023  2023
# 3    11675450      50091  ATP Beijing, China Men Singles 2023  2023
# 4    11675446      50091  ATP Beijing, China Men Singles 2023  2023
# ..        ...        ...                                  ...   ...
# 759  11701147      55261    ITF Egypt 15A, Women Singles 2023  2023
# 760  11701143      55261    ITF Egypt 15A, Women Singles 2023  2023
# 761  11701139      55261    ITF Egypt 15A, Women Singles 2023  2023
# 762  11701137      55261    ITF Egypt 15A, Women Singles 2023  2023
# 763  11701141      55261    ITF Egypt 15A, Women Singles 2023  2023
#
# [764 rows x 4 columns]

# %%
time_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_match_parquet/time"):
    single_time = pd.read_parquet("drive/MyDrive/raw/raw_match_parquet/time/" + file)
    time_dataframe = pd.concat([time_dataframe, single_time], axis="rows", ignore_index=True)

time_dataframe
# Out:
#      match_id period_1 period_2 period_3 period_4 period_5  \
# 0    11699346     1702     2100     None     None     None
# 1    11699272     None     None     None     None     None
# 2    11699341     1800     3063     None     None     None
# 3    11699271     3371     3121     None     None     None
# 4    11699343     None     None     None     None     None
# ..        ...      ...      ...      ...      ...      ...
# 769  11699156     2732     3576      799     None     None
# 770  11699164     1612     1201     None     None     None
# 771  11699154     3819     2213      762     None     None
# 772  11699155     1448     1851     None     None     None
# 773  11698947     None     None     None     None     None
#
#     current_period_start_timestamp
# 0                       1696149649
# 1                             None
# 2                       1696161809
# 3                       1696167288
# 4                       1696149708
# ..                             ...
# 769                     1696178422
# 770                     1696175888
# 771                     1696180933
# 772                     1696179545
# 773                           None
#
# [774 rows x 7 columns]

# %%
tournament_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_match_parquet/tournament"):
    single_tournament = pd.read_parquet("drive/MyDrive/raw/raw_match_parquet/tournament/" + file)
    tournament_dataframe = pd.concat([tournament_dataframe, single_tournament], axis="rows", ignore_index=True)

tournament_dataframe
# Out:
#      match_id  tournament_id  \
# 0    11675449         121516
# 1    11675448         121516
# 2    11675444         121516
# 3    11675450         121516
# 4    11675446         121516
# ..        ...            ...
# 779  11701147         121846
# 780  11701143         121846
# 781  11701139         121846
# 782  11701137         121846
# 783  11701141         121846
#
#                                        tournament_name  \
# 0                                       Beijing, China
# 1                                       Beijing, China
# 2                                       Beijing, China
# 3                                       Beijing, China
# 4                                       Beijing, China
# ..                                                 ...
# 779  Sharm ElSheikh, Singles Qualifying, W-ITF-EGY-15A
# 780  Sharm ElSheikh, Singles Qualifying, W-ITF-EGY-15A
# 781  Sharm ElSheikh, Singles Qualifying, W-ITF-EGY-15A
# 782  Sharm ElSheikh, Singles Qualifying, W-ITF-EGY-15A
# 783  Sharm ElSheikh, Singles Qualifying, W-ITF-EGY-15A
#
#                                      tournament_slug tournament_unique_id  \
# 0                                      beijing-china                 None
# 1                                      beijing-china                 None
# 2                                      beijing-china                 None
# 3                                      beijing-china                 None
# 4                                      beijing-china                 None
# ..                                               ...                  ...
# 779  sharm-elsheikh-singles-qualifying-w-itf-egy-15a                 None
# 780  sharm-elsheikh-singles-qualifying-w-itf-egy-15a                 None
# 781  sharm-elsheikh-singles-qualifying-w-itf-egy-15a                 None
# 782  sharm-elsheikh-singles-qualifying-w-itf-egy-15a                 None
# 783  sharm-elsheikh-singles-qualifying-w-itf-egy-15a                 None
#
#     tournament_category_name tournament_category_slug  user_count  \
# 0                        ATP                      atp        2423
# 1                        ATP                      atp        2423
# 2                        ATP                      atp        2423
# 3                        ATP                      atp        2423
# 4                        ATP                      atp        2423
# ..                       ...                      ...         ...
# 779                ITF Women                itf-women          10
# 780                ITF Women                itf-women          10
# 781                ITF Women                itf-women          10
# 782                ITF Women                itf-women          10
# 783                ITF Women                itf-women          10
#
#            ground_type tennis_points  has_event_player_statistics  \
# 0    Hardcourt outdoor           500                        False
# 1    Hardcourt outdoor           500                        False
# 2    Hardcourt outdoor           500                        False
# 3    Hardcourt outdoor           500                        False
# 4    Hardcourt outdoor           500                        False
# ..                 ...           ...                          ...
# 779  Hardcourt outdoor          None                        False
# 780  Hardcourt outdoor          None                        False
# 781  Hardcourt outdoor          None                        False
# 782  Hardcourt outdoor          None                        False
# 783  Hardcourt outdoor          None                        False
#
#      crowd_sourcing_enabled  has_performance_graph_feature  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
# ..                      ...                            ...
# 779                   False                          False
# 780                   False                          False
# 781                   False                          False
# 782                   False                          False
# 783                   False                          False
#
#      display_inverse_home_away_teams  priority  competition_type
# 0                              False         0                 2
# 1                              False         0                 2
# 2                              False         0                 2
# 3                              False         0                 2
# 4                              False         0                 2
# ..                               ...       ...               ...
# 779                            False         0                 2
# 780                            False         0                 2
# 781                            False         0                 2
# 782                            False         0                 2
# 783                            False         0                 2
#
# [784 rows x 16 columns]

# %%
venue_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_match_parquet/venue"):
    single_venue = pd.read_parquet("drive/MyDrive/raw/raw_match_parquet/venue/" + file)
    venue_dataframe = pd.concat([venue_dataframe, single_venue], axis="rows", ignore_index=True)

venue_dataframe
# Out:
#      match_id             city        stadium  venue_id country
# 0    11675449          Beijing  Diamond Court     26769   China
# 1    11675448          Beijing    LOTUS COURT      2102   China
# 2    11675444          Beijing  Diamond Court     26769   China
# 3    11675450          Beijing    LOTUS COURT      2102   China
# 4    11675446          Beijing  Diamond Court     26769   China
# ..        ...              ...            ...       ...     ...
# 758  11701147  Sharm El Sheikh        Court 1     28802   Egypt
# 759  11701143  Sharm El Sheikh        Court 4     28799   Egypt
# 760  11701139  Sharm El Sheikh        Court 3     17612   Egypt
# 761  11701137  Sharm El Sheikh        Court 1     28802   Egypt
# 762  11701141  Sharm El Sheikh        Court 3     17612   Egypt
#
# [763 rows x 5 columns]

# %%
odds_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_odds_parquet"):
    single_odds = pd.read_parquet("drive/MyDrive/raw/raw_odds_parquet/" + file)
    odds_dataframe = pd.concat([odds_dataframe, single_odds], axis="rows", ignore_index=True)

odds_dataframe
# Out:
#      match_id  market_id       market_name  is_live  suspended  \
# 0    11675449          1         full_time    False      False
# 1    11675449          1         full_time    False      False
# 2    11675449         11  first_set_winner    False      False
# 3    11675449         11  first_set_winner    False      False
# 4    11675449         12   total_games_won    False      False
# ..        ...        ...               ...      ...        ...
# 843  11701627          1         full_time    False      False
# 844  11703470          1         full_time    False      False
# 845  11703470          1         full_time    False      False
# 846  11702248          1         full_time    False      False
# 847  11702248          1         full_time    False      False
#
#     initial_fractional_value fractional_value choice_name  choice_source_id  \
# 0                       8/15           53/100           1        1345172972
# 1                        6/4              3/2           2        1345173162
# 2                        4/9             8/13           1        1345175703
# 3                       13/8              6/5           2        1345175785
# 4                       8/11              5/6        Over        1346185875
# ..                       ...              ...         ...               ...
# 843                      9/4              9/4           2        1358885924
# 844                      4/6              4/6           1        1362356775
# 845                    11/10            11/10           2        1362356896
# 846                     8/13             8/13           1        1360686761
# 847                      6/5              6/5           2        1360686797
#
#     winnig  change
# 0     True       1
# 1    False       0
# 2    False       1
# 3     True      -1
# 4     True       1
# ..     ...     ...
# 843   True       0
# 844   True       0
# 845  False       0
# 846  False       0
# 847   True       0
#
# [848 rows x 11 columns]

# %%
point_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_point_by_point_parquet"):
    single_point = pd.read_parquet("drive/MyDrive/raw/raw_point_by_point_parquet/" + file)
    point_dataframe = pd.concat([point_dataframe, single_point], axis="rows", ignore_index=True)

point_dataframe
# Out:
#        match_id  set_id  game_id  point_id home_point away_point  \
# 0      11675449       3        7         0         15          0
# 1      11675449       3        7         1         30          0
# 2      11675449       3        7         2         40          0
# 3      11675449       3        7         3         40         15
# 4      11675449       3        6         0         15          0
# ...         ...     ...      ...       ...        ...        ...
# 22875  11702248       1        2         2         40          0
# 22876  11702248       1        1         0         15          0
# 22877  11702248       1        1         1         15         15
# 22878  11702248       1        1         2         30         15
# 22879  11702248       1        1         3         40         15
#
#        point_description  home_point_type  away_point_type  home_score  \
# 0                      0                1                5           6
# 1                      0                1                5           6
# 2                      2                3                5           6
# 3                      0                3                1           6
# 4                      0                1                5           5
# ...                  ...              ...              ...         ...
# 22875                  0                2                5           2
# 22876                  0                1                5           1
# 22877                  0                5                1           1
# 22878                  0                1                5           1
# 22879                  0                1                5           1
#
#        away_score  serving  scoring
# 0               1        2        1
# 1               1        2        1
# 2               1        2        1
# 3               1        2        1
# 4               1        1        1
# ...           ...      ...      ...
# 22875           0        2        1
# 22876           0        1        1
# 22877           0        1        1
# 22878           0        1        1
# 22879           0        1        1
#
# [22880 rows x 13 columns]

# %%
statistics_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_statistics_parquet"):
    single_stats = pd.read_parquet("drive/MyDrive/raw/raw_statistics_parquet/" + file)
    statistics_dataframe = pd.concat([statistics_dataframe, single_stats], axis="rows", ignore_index=True)

statistics_dataframe
# Out:
#        match_id period statistic_category_name              statistic_name  \
# 0      11675449    ALL                 service                        aces
# 1      11675449    ALL                 service               double_faults
# 2      11675449    ALL                 service                 first_serve
# 3      11675449    ALL                 service                second_serve
# 4      11675449    ALL                 service          first_serve_points
# ...         ...    ...                     ...                         ...
# 12258  11702248    3RD                  return   first_serve_return_points
# 12259  11702248    3RD                  return  second_serve_return_points
# 12260  11702248    3RD                  return         return_games_played
# 12261  11702248    3RD                  return      break_points_converted
# 12262  11702248    3RD           miscellaneous                   tiebreaks
#
#          home_stat     away_stat  compare_code statistic_type value_type  \
# 0                9             4             1       positive      event
# 1                1             1             3       negative      event
# 2      70/90 (78%)  71/103 (69%)             1       positive       team
# 3      19/20 (95%)   31/32 (97%)             2       positive       team
# 4      43/70 (61%)   37/71 (52%)             1       positive       team
# ...            ...           ...           ...            ...        ...
# 12258   7/19 (36%)    7/12 (58%)             2       positive       team
# 12259   7/11 (63%)    6/10 (60%)             1       positive       team
# 12260            5             4             1       positive      event
# 12261            2             3             2       positive      event
# 12262            0             0             3       positive      event
#
#        home_value  away_value  home_total  away_total
# 0               9           4         NaN         NaN
# 1               1           1         NaN         NaN
# 2              70          71        90.0       103.0
# 3              19          31        20.0        32.0
# 4              43          37        70.0        71.0
# ...           ...         ...         ...         ...
# 12258           7           7        19.0        12.0
# 12259           7           6        11.0        10.0
# 12260           5           4         NaN         NaN
# 12261           2           3         NaN         NaN
# 12262           0           0         NaN         NaN
#
# [12263 rows x 13 columns]

# %%
power_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_tennis_power_parquet"):
    single_power = pd.read_parquet("drive/MyDrive/raw/raw_tennis_power_parquet/" + file)
    power_dataframe = pd.concat([power_dataframe, single_power], axis="rows", ignore_index=True)

power_dataframe
# Out:
#       match_id  set_num  game_num  value  break_occurred
# 0     11675449        1         1  10.00           False
# 1     11675449        1         2 -53.32           False
# 2     11675449        1         3 -66.36            True
# 3     11675449        1         4  14.16            True
# 4     11675449        1         5  49.72           False
# ...        ...      ...       ...    ...             ...
# 3580  11702248        3         5  55.92            True
# 3581  11702248        3         6 -29.52            True
# 3582  11702248        3         7 -10.00           False
# 3583  11702248        3         8 -70.32            True
# 3584  11702248        3         9 -14.82           False
#
# [3585 rows x 5 columns]

# %%
votes_dataframe = pd.DataFrame()
for file in os.listdir("drive/MyDrive/raw/raw_votes_parquet"):
    single_votes = pd.read_parquet("drive/MyDrive/raw/raw_votes_parquet/" + file)
    votes_dataframe = pd.concat([votes_dataframe, single_votes], axis="rows", ignore_index=True)

votes_dataframe
# Out:
#      match_id  home_vote  away_vote
# 0    11675449       5621       1318
# 1    11675448        584       3616
# 2    11675444       4150       1016
# 3    11675450        563       4603
# 4    11675446       6101       2938
# ..        ...        ...        ...
# 769  11701147         11          3
# 770  11701143          2          3
# 771  11701139          5          2
# 772  11701137          7          2
# 773  11701141          2          5
#
# [774 rows x 3 columns]

# %% [markdown]
# **Exercise 5**

# %%
set_count = power_dataframe.groupby('match_id')['set_num'].max()
average_number_of_sets = set_count.mean()
print(f"Average number of sets in a match :", int(average_number_of_sets))
# Out:
# Average number of sets in a match : 2

# %% [markdown]
# **Exercise 6**

# %%
win = odds_dataframe[odds_dataframe['winnig']==1]
merged_df3 = pd.merge(win, at_dataframe, on='match_id', how='left')
winner = merged_df3.groupby('name').agg({'winnig' : 'size'})
most_win_per_person = winner.max()
most_win_per_person
most_successful_tennis_players = winner[winner['winnig']==6]
merged_df4 = pd.merge(most_successful_tennis_players, at_dataframe, on='name', how='left')
merged_df4
most_successful_countries = merged_df4.groupby('name').agg({'country' : 'unique'})

most_successful_countries
# Out:
#                country
# name
# Međedović H.  [Serbia]
# Ruud C.       [Norway]
# Samsonova L.  [Russia]
# Sinner J.      [Italy]

# %% [markdown]
# **Exercise 7**

# %%
win = odds_dataframe[odds_dataframe['winnig']==1]
merged_df1 = pd.merge(win, ht_dataframe, on='match_id', how='left')
winner = merged_df1.groupby('name').agg({'winnig' : 'size'})
most_win_per_person = winner.max()
most_successful_tennis_players = winner[winner['winnig']==6]
merged_df2 = pd.merge(most_successful_tennis_players, ht_dataframe, on='name', how='left')
most_successful_countries = merged_df2.groupby('name').agg({'country' : 'unique'})

most_successful_countries
# Out:
#                      country
# name
# Alcaraz C.           [Spain]
# Kvitová P.  [Czech Republic]
# Ofner S.           [Austria]
# Zverev A.          [Germany]

# %%
aces = statistics_dataframe[statistics_dataframe['statistic_name']=='aces']
aces_per_match = aces.groupby('match_id').size()
mean_aces_per_match = aces_per_match.mean()
print(f"Mean number of aces per match:", mean_aces_per_match)
# Out:
# Mean number of aces per match: 3.3062200956937797

# %% [markdown]
# **Exercise 8**

# %%
double_faults = statistics_dataframe[statistics_dataframe['statistic_name']=='double_faults']
merged_df = pd.merge(double_faults, at_dataframe, on='match_id', how='left')
double_faults_based_on_gender = merged_df.groupby('gender').agg({'statistic_name' : 'size'})
double_faults_based_on_gender
# Out:
#         statistic_name
# gender
# F                  309
# M                  169

# %%
double_faults = statistics_dataframe[statistics_dataframe['statistic_name']=='double_faults']
merged_df = pd.merge(double_faults, ht_dataframe, on='match_id', how='left')
double_faults_based_on_gender = merged_df.groupby('gender').agg({'statistic_name' : 'size'})
double_faults_based_on_gender
# Out:
#         statistic_name
# gender
# F                  317
# M                  240
